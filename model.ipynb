# %%
from transformers import MarianMTModel, MarianTokenizer

# Define model names
model_name_hi = "Helsinki-NLP/opus-mt-en-hi"
model_name_mr = "Helsinki-NLP/opus-mt-en-mr"

# Load and save Hindi model
tokenizer_hi = MarianTokenizer.from_pretrained(model_name_hi)
model_hi = MarianMTModel.from_pretrained(model_name_hi)
tokenizer_hi.save_pretrained("./saved_models/en-hi")
model_hi.save_pretrained("./saved_models/en-hi")

# Load and save Marathi model
tokenizer_mr = MarianTokenizer.from_pretrained(model_name_mr)
model_mr = MarianMTModel.from_pretrained(model_name_mr)
tokenizer_mr.save_pretrained("./saved_models/en-mr")
model_mr.save_pretrained("./saved_models/en-mr")

print("✅ Models Saved Successfully!")
# Out:
# c:\Users\sanke\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# c:\Users\sanke\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# ✅ Publicly available IndicTrans v1 models
model_name_hi = "ai4bharat/indictrans-en-hi"
model_name_mr = "ai4bharat/indictrans-en-mr"

# Load Hindi Model
tokenizer_hi = AutoTokenizer.from_pretrained(model_name_hi)
model_hi = AutoModelForSeq2SeqLM.from_pretrained(model_name_hi)

# Load Marathi Model
tokenizer_mr = AutoTokenizer.from_pretrained(model_name_mr)
model_mr = AutoModelForSeq2SeqLM.from_pretrained(model_name_mr)

print("✅ Models Loaded Successfully!")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\sanke\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File c:\Users\sanke\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/ai4bharat/indictrans-en-hi/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...
